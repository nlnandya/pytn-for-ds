# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
my_series = pd.Series([2,3,4,4,32,334,332])
my_series
# Out:
# 0      2
# 1      3
# 2      4
# 3      4
# 4     32
# 5    334
# 6    332
# dtype: int64

# %%
my_series.index = pd.RangeIndex(start=0, step=2, stop=14)
my_series
# Out:
# 0       2
# 2       3
# 4       4
# 6       4
# 8      32
# 10    334
# 12    332
# dtype: int64

# %%
my_series[6]
# Out:
# 4

# %%
my_series_2 = pd.Series([12,23,55,67], index=["a","b","c","d"])
my_series_2
# Out:
# a    12
# b    23
# c    55
# d    67
# dtype: int64

# %%
my_series_2.index = ["d","c","b","a"]
my_series_2
# Out:
# d    12
# c    23
# b    55
# a    67
# dtype: int64

# %%
#Pandas -> dictionary
mySeries = pd.Series({"name": "nan", "age": 22})
mySeries
# Out:
# name    nan
# age      22
# dtype: object

# %%
range
# Out:
# DatetimeIndex(['2021-07-09', '2021-07-11', '2021-07-13', '2021-07-15',
#                '2021-07-17', '2021-07-19', '2021-07-21', '2021-07-23',
#                '2021-07-25', '2021-07-27', '2021-07-29', '2021-07-31',
#                '2021-08-02', '2021-08-04', '2021-08-06', '2021-08-08',
#                '2021-08-10', '2021-08-12', '2021-08-14', '2021-08-16',
#                '2021-08-18', '2021-08-20', '2021-08-22', '2021-08-24',
#                '2021-08-26', '2021-08-28', '2021-08-30', '2021-09-01',
#                '2021-09-03', '2021-09-05', '2021-09-07', '2021-09-09',
#                '2021-09-11', '2021-09-13', '2021-09-15', '2021-09-17',
#                '2021-09-19', '2021-09-21', '2021-09-23', '2021-09-25',
#                '2021-09-27', '2021-09-29', '2021-10-01', '2021-10-03',
#                '2021-10-05', '2021-10-07', '2021-10-09', '2021-10-11',
#                '2021-10-13', '2021-10-15', '2021-10-17', '2021-10-19',
# ...

# %%
range = pd.date_range("7/09/2021", periods=60, freq="2D")
valueluw = np.random.random([60])

myDateSeries = pd.Series(valueluw, index = range)

# %%
filteredData = myDateSeries[myDateSeries >= 0.5]
filteredData.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Frame

# %%
studentDataFrame = pd.DataFrame({
    "name": ["nan", "suci", "ilham"],
    "age": [22, 21, 20],
    "ipk": ["3.80", "3.70", "32.00"],
    "sks": [21, 22, 23]
})
;studentDataFrame
# Out:
#     name  age    ipk  sks
# 0    nan   22   3.80   21
# 1   suci   21   3.70   22
# 2  ilham   20  32.00   23

# %%
studentDataFrame.filter(items=["name", "ipk"], axis="columns")
# Out:
#     name    ipk
# 0    nan   3.80
# 1   suci   3.70
# 2  ilham  32.00

# %%
studentDataFrame["kredit"] = studentDataFrame["sks"] *studentDataFrame["ipk"]
# Out:
#     name  age    ipk  sks
# 0    nan   22   3.80   21
# 1   suci   21   3.70   22
# 2  ilham   20  32.00   23

# %%
#mengganti nama kolom

studentDataFrame.rename(columns = {"name":"names"})
# Out:
#    names  age    ipk  sks
# 0    nan   22   3.80   21
# 1   suci   21   3.70   22
# 2  ilham   20  32.00   23

# %%
studentDataFrame.append({"names":"maimun", "age":24, "ipk":28.00, "sks":24}, ignore_index=True)
# Out:
#     name  age    ipk  sks   names
# 0    nan   22   3.80   21     NaN
# 1   suci   21   3.70   22     NaN
# 2  ilham   20  32.00   23     NaN
# 3    NaN   24   28.0   24  maimun

# %%
studentDataFrame
# Out:
#     name  age    ipk  sks
# 0    nan   22   3.80   21
# 1   suci   21   3.70   22
# 2  ilham   20  32.00   23

# %%
studentDataFrame.filter(regex="^m", axis=0)
# Out:
# Empty DataFrame
# Columns: [name, age, ipk, sks]
# Index: []

# %%
#filter 
studentDataFrame[studentDataFrame.name.str.contains("i")]
# Out:
#     name  age    ipk  sks
# 1   suci   21   3.70   22
# 2  ilham   20  32.00   23

# %%
studentDataFrame[studentDataFrame.name.str.contains("am$")]
# Out:
#     name  age    ipk  sks
# 2  ilham   20  32.00   23

# %%
movieDB = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv")

# %%
movieDB
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movieDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
#filter film dengan duration <= 100, star_rating > 7, urutkan dari rating tertinggi

filter2 = movieDB["star_rating"] >7
filter2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 974    True
# 975    True
# 976    True
# 977    True
# 978    True
# Name: star_rating, Length: 979, dtype: bool

# %%
#no2

filter2 = movieDB["star_rating"] >7
filter2

# %%
#no 3
#sort

movieDB.sort_values("star_rating", ascending=False)
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 3            9.0           The Dark Knight          PG-13  Action       152
# 4            8.9              Pulp Fiction              R   Crime       154
# ..           ...                       ...            ...     ...       ...
# 948          7.4                Frances Ha              R  Comedy        86
# 949          7.4                Home Alone             PG  Comedy       103
# 950          7.4                     Bound              R   Crime       108
# 951          7.4             Sleepy Hollow              R   Drama       105
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...

# %%
#filter berdasarkan judul

movies[movies.title.str.includes("^12")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-355ffe3ddb06> in <module>
#       1 #filter berdasarkan judul
#       2
# ----> 3 movieDB[movieDB.title.str.includes("^12")]
#
# AttributeError: 'StringMethods' object has no attribute 'includes'

# %%
import re

movieDB[movieDB.title.str.contains("^sp", flags=re.IGNORECASE)]
# Out:
#      star_rating                                       title content_rating  \
# 30           8.6                               Spirited Away             PG
# 243          8.1  Spring, Summer, Fall, Winter... and Spring              R
# 385          8.0                                   Spartacus          PG-13
# 687          7.7                                  Spellbound        UNRATED
#
#          genre  duration                                        actors_list
# 30   Animation       125  [u'Daveigh Chase', u'Suzanne Pleshette', u'Miy...
# 243      Drama       103    [u'Ki-duk Kim', u'Yeong-su Oh', u'Jong-ho Kim']
# 385     Action       197  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 687  Film-Noir       111  [u'Ingrid Bergman', u'Gregory Peck', u'Michael...

# %%
#group

groupedMovie = movieDB.groupby(["genre"])["title"]

groupedMovie.describe()
# Out:
#           count unique                                  top freq
# genre
# Action      136    136              Raiders of the Lost Ark    1
# Adventure    75     74                            True Grit    2
# Animation    62     62                               Frozen    1
# Biography    77     77                          October Sky    1
# Comedy      156    156                         Modern Times    1
# Crime       124    123      The Girl with the Dragon Tattoo    2
# Drama       278    278                   The Killing Fields    1
# Family        2      2  Willy Wonka & the Chocolate Factory    1
# Fantasy       1      1            The City of Lost Children    1
# Film-Noir     3      3                           Spellbound    1
# History       1      1                  Battleship Potemkin    1
# Horror       29     28                              Dracula    2
# Mystery      16     16                          Source Code    1
# ...

# %%
for key, values in groupedMovie.groups.items():
    print(key)
# Out:
# Action
# Adventure
# Animation
# Biography
# Comedy
# Crime
# Drama
# Family
# Fantasy
# Film-Noir
# History
# Horror
# Mystery
# Sci-Fi
# Thriller
# Western

# %%
for key, value in groupedMovie.groups.items():
    print(value)
    for valInx in value:
        print(movieDB[movieDB.genre == key])
# Out:
# Int64Index([  3,  11,  12,  19,  20,  36,  37,  43,  44,  45,
#             ...
#             884, 885, 896, 906, 908, 918, 954, 963, 967, 976],
#            dtype='int64', length=136)
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# ...

# %%
#grafik

summary = movieDB.pivot_table(index=["genre"],
                              values = ["duration", "star_rating"], 
                              aggfunc={"duration":"mean", "star_rating":"mean"})
summary
# Out:
#              duration  star_rating
# genre
# Action     126.485294     7.884559
# Adventure  134.840000     7.933333
# Animation   96.596774     7.914516
# Biography  131.844156     7.862338
# Comedy     107.602564     7.822436
# Crime      122.298387     7.916935
# Drama      126.539568     7.902518
# Family     107.500000     7.850000
# Fantasy    112.000000     7.700000
# Film-Noir   97.333333     8.033333
# History     66.000000     8.000000
# Horror     102.517241     7.806897
# Mystery    115.625000     7.975000
# Sci-Fi     109.000000     7.920000
# Thriller   114.200000     7.680000
# Western    136.666667     8.255556

# %%
summary.plot.bar(subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'duration'}, xlabel='genre'>,
#        <AxesSubplot:title={'center':'star_rating'}, xlabel='genre'>],
#       dtype=object)

# %%
movieDB.loc[movieDB.genre == "Thriller"]
# Out:
#      star_rating                      title content_rating     genre  \
# 350          8.0          Shadow of a Doubt       APPROVED  Thriller
# 496          7.8                     Misery              R  Thriller
# 728          7.6         La piel que habito              R  Thriller
# 848          7.5  The Man Who Knew Too Much             PG  Thriller
# 902          7.5                     Frenzy              R  Thriller
#
#      duration                                        actors_list
# 350       108  [u'Teresa Wright', u'Joseph Cotten', u'Macdona...
# 496       107  [u'James Caan', u'Kathy Bates', u'Richard Farn...
# 728       120  [u'Antonio Banderas', u'Elena Anaya', u'Jan Co...
# 848       120  [u'James Stewart', u'Doris Day', u'Brenda de B...
# 902       116   [u'Jon Finch', u'Barry Foster', u'Alec McCowen']

# %%
movieDB.iloc[200:290]
# Out:
#      star_rating                                 title content_rating  \
# 200          8.1                           Le Samourai             PG
# 201          8.1                      12 Years a Slave              R
# 202          8.1  La leggenda del pianista sull'oceano              R
# 203          8.1                                 8 1/2      NOT RATED
# 204          8.1                               Ben-Hur              G
# ..           ...                                   ...            ...
# 285          8.1                      Bringing Up Baby       APPROVED
# 286          8.1     The Diving Bell and the Butterfly          PG-13
# 287          8.1                       His Girl Friday       APPROVED
# 288          8.1                           Sling Blade              R
# 289          8.1        All Quiet on the Western Front        UNRATED
#
#          genre  duration                                        actors_list
# ...
