# %%
import pandas as pd
import numpy as np

# %%
#data example = canada imigration data
df_can = pd.read_excel("Canada.xlsx", sheet_name="Canada by Citizenship", skiprows=20, usecols="A:AQ")

# %%
#data teratas
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
#data terbawah
df_can.tail()
# Out:
#            Type    Coverage    OdName  AREA AreaName  REG         RegName  \
# 192  Immigrants  Foreigners     Yemen   935     Asia  922    Western Asia
# 193  Immigrants  Foreigners    Zambia   903   Africa  910  Eastern Africa
# 194  Immigrants  Foreigners  Zimbabwe   903   Africa  910  Eastern Africa
# 195  Immigrants  Foreigners   Unknown   999    World  999           World
# 196  Immigrants        Both     Total   999    World  999           World
#
#      DEV             DevName    1980  ...    2004    2005    2006    2007  \
# 192  902  Developing regions       1  ...     124     161     140     122
# 193  902  Developing regions      11  ...      56      91      77      71
# 194  902  Developing regions      72  ...    1450     615     454     663
# 195  999               World   44000  ...    3739    4785    4583    4348
# 196  999               World  143137  ...  235822  262242  251640  236753
#
#        2008    2009    2010    2011    2012    2013
# ...

# %%
#melihat list column
df_can.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
df_can.drop(["Coverage", "AREA", "REG", "DEV", "Type"], axis=1, inplace=True)

# %%
df_can.columns.values
# Out:
# array(['OdName', 'AreaName', 'RegName', 'DevName', 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], dtype=object)

# %%
df_can.rename(columns={"OdName":"Country", "AreaName":"Continent", "RegName":"Region"},inplace=True)

# %%
df_can
# Out:
#             Country Continent           Region             DevName    1980  \
# 0       Afghanistan      Asia    Southern Asia  Developing regions      16
# 1           Albania    Europe  Southern Europe   Developed regions       1
# 2           Algeria    Africa  Northern Africa  Developing regions      80
# 3    American Samoa   Oceania        Polynesia  Developing regions       0
# 4           Andorra    Europe  Southern Europe   Developed regions       0
# ..              ...       ...              ...                 ...     ...
# 192           Yemen      Asia     Western Asia  Developing regions       1
# 193          Zambia    Africa   Eastern Africa  Developing regions      11
# 194        Zimbabwe    Africa   Eastern Africa  Developing regions      72
# 195         Unknown     World            World               World   44000
# 196           Total     World            World               World  143137
#
# ...

# %%
df_can["Total"] = df_can.sum(axis=1)

# %%
df_can
# Out:
#             Country Continent           Region             DevName    1980  \
# 0       Afghanistan      Asia    Southern Asia  Developing regions      16
# 1           Albania    Europe  Southern Europe   Developed regions       1
# 2           Algeria    Africa  Northern Africa  Developing regions      80
# 3    American Samoa   Oceania        Polynesia  Developing regions       0
# 4           Andorra    Europe  Southern Europe   Developed regions       0
# ..              ...       ...              ...                 ...     ...
# 192           Yemen      Asia     Western Asia  Developing regions       1
# 193          Zambia    Africa   Eastern Africa  Developing regions      11
# 194        Zimbabwe    Africa   Eastern Africa  Developing regions      72
# 195         Unknown     World            World               World   44000
# 196           Total     World            World               World  143137
#
# ...

# %%
df_can.isnull().sum()
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_can
# Out:
#             Country Continent           Region             DevName    1980  \
# 0       Afghanistan      Asia    Southern Asia  Developing regions      16
# 1           Albania    Europe  Southern Europe   Developed regions       1
# 2           Algeria    Africa  Northern Africa  Developing regions      80
# 3    American Samoa   Oceania        Polynesia  Developing regions       0
# 4           Andorra    Europe  Southern Europe   Developed regions       0
# ..              ...       ...              ...                 ...     ...
# 192           Yemen      Asia     Western Asia  Developing regions       1
# 193          Zambia    Africa   Eastern Africa  Developing regions      11
# 194        Zimbabwe    Africa   Eastern Africa  Developing regions      72
# 195         Unknown     World            World               World   44000
# 196           Total     World            World               World  143137
#
# ...

# %%
simigran_by_country = df_can.drop(["Continent", "Region", "DevName"], axis=1)

# %%
simigran_by_country
# Out:
#             Country    1980    1981    1982   1983   1984   1985   1986  \
# 0       Afghanistan      16      39      39     47     71    340    496
# 1           Albania       1       0       0      0      0      0      1
# 2           Algeria      80      67      71     69     63     44     69
# 3    American Samoa       0       1       0      0      0      0      0
# 4           Andorra       0       0       0      0      0      0      2
# ..              ...     ...     ...     ...    ...    ...    ...    ...
# 192           Yemen       1       2       1      6      0     18      7
# 193          Zambia      11      17      11      7     16      9     15
# 194        Zimbabwe      72     114     102     44     32     29     43
# 195         Unknown   44000   18078   16904  13635  14855  14368  13303
# 196           Total  143137  128641  121175  89185  88272  84346  99351
#
#        1987    1988  ...    2005    2006    2007    2008    2009    2010  \
# ...

# %%
simigran_by_country.set_index("Country", inplace=True)

# %%
simigran_by_country
# Out:
#                   1980    1981    1982   1983   1984   1985   1986    1987  \
# Country
# Afghanistan         16      39      39     47     71    340    496     741
# Albania              1       0       0      0      0      0      1       2
# Algeria             80      67      71     69     63     44     69     132
# American Samoa       0       1       0      0      0      0      0       1
# Andorra              0       0       0      0      0      0      2       0
# ...                ...     ...     ...    ...    ...    ...    ...     ...
# Yemen                1       2       1      6      0     18      7      12
# Zambia              11      17      11      7     16      9     15      23
# Zimbabwe            72     114     102     44     32     29     43      68
# Unknown          44000   18078   16904  13635  14855  14368  13303   17304
# Total           143137  128641  121175  89185  88272  84346  99351  152075
#
# ...

# %%
# find by key

simigran_by_country.loc["Algeria"]
# Out:
# 1980        80
# 1981        67
# 1982        71
# 1983        69
# 1984        63
# 1985        44
# 1986        69
# 1987       132
# 1988       242
# 1989       434
# 1990       491
# 1991       872
# 1992       795
# 1993       717
# 1994       595
# 1995      1106
# 1996      2054
# 1997      1842
# 1998      2292
# 1999      2389
# 2000      2867
# 2001      3418
# 2002      3406
# 2003      3072
# 2004      3616
# 2005      3626
# 2006      4807
# 2007      3623
# 2008      4005
# 2009      5393
# 2010      4752
# 2011      4325
# 2012      3774
# 2013      4331
# Total    69439
# Name: Algeria, dtype: int64

# %%
#find by key with speciific column

simigran_by_country.loc["Algeria", range(1981, 1985)]
# Out:
# 1981    67
# 1982    71
# 1983    69
# 1984    63
# Name: Algeria, dtype: int64

# %%
df_can.set_index(["Country"], inplace=True)

# %%
condition = df_can[df_can["Continent"]=="Europe"]

# %%
condition
# Out:
#                                                    Continent           Region  \
# Country
# Albania                                               Europe  Southern Europe
# Andorra                                               Europe  Southern Europe
# Austria                                               Europe   Western Europe
# Belarus                                               Europe   Eastern Europe
# Belgium                                               Europe   Western Europe
# Bosnia and Herzegovina                                Europe  Southern Europe
# Bulgaria                                              Europe   Eastern Europe
# Croatia                                               Europe  Southern Europe
# Czech Republic                                        Europe   Eastern Europe
# Denmark                                               Europe  Northern Europe
# Estonia                                               Europe  Northern Europe
# ...

# %%
df_can[(df_can["Continent"]== "Europe") & (df_can["Region"]=="Southern Europe")]
# Out:
#                                           Continent           Region  \
# Country
# Albania                                      Europe  Southern Europe
# Andorra                                      Europe  Southern Europe
# Bosnia and Herzegovina                       Europe  Southern Europe
# Croatia                                      Europe  Southern Europe
# Greece                                       Europe  Southern Europe
# Italy                                        Europe  Southern Europe
# Malta                                        Europe  Southern Europe
# Montenegro                                   Europe  Southern Europe
# Portugal                                     Europe  Southern Europe
# San Marino                                   Europe  Southern Europe
# Serbia                                       Europe  Southern Europe
# Slovenia                                     Europe  Southern Europe
# ...

# %%
df_can[(df_can["Continent"]=="Europe") | (df_can["Continent"]=="World") | (df_can["Continent"]=="Africa")]
# Out:
#                Continent           Region             DevName    1980    1981  \
# Country
# Albania           Europe  Southern Europe   Developed regions       1       0
# Algeria           Africa  Northern Africa  Developing regions      80      67
# Andorra           Europe  Southern Europe   Developed regions       0       0
# Angola            Africa    Middle Africa  Developing regions       1       3
# Austria           Europe   Western Europe   Developed regions     234     238
# ...                  ...              ...                 ...     ...     ...
# Western Sahara    Africa  Northern Africa  Developing regions       0       0
# Zambia            Africa   Eastern Africa  Developing regions      11      17
# Zimbabwe          Africa   Eastern Africa  Developing regions      72     114
# Unknown            World            World               World   44000   18078
# Total              World            World               World  143137  128641
#
# ...

# %%
df_can["Continent"] == "Asia"
# Out:
# Country
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Unknown           False
# Total             False
# Name: Continent, Length: 197, dtype: bool

# %%
#visualozation
#matplotlib Pyplot

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
afghanistanImigran = df_can.loc["Afghanistan", range(1980, 2012)]

# %%
afghanistanImigran
# Out:
# 1980      16
# 1981      39
# 1982      39
# 1983      47
# 1984      71
# 1985     340
# 1986     496
# 1987     741
# 1988     828
# 1989    1076
# 1990    1028
# 1991    1378
# 1992    1170
# 1993     713
# 1994     858
# 1995    1537
# 1996    2212
# 1997    2555
# 1998    1999
# 1999    2395
# 2000    3326
# 2001    4067
# 2002    3697
# 2003    3479
# 2004    2978
# 2005    3436
# 2006    3009
# 2007    2652
# 2008    2111
# 2009    1746
# 2010    1758
# 2011    2203
# Name: Afghanistan, dtype: object

# %%
afghanistanImigran.plot()

plt.title("Immigration from Afghanistan")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %%
years = range(1980, 2014)

# %%
years
# Out:
# range(1980, 2014)

# %%
#china dan India

# %%
china_India = df_can.loc[["China", "India"], years]

# %%
china_India
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
china_India.plot(kind="line", figsize=(20,9))
# Out:
# <AxesSubplot:>

# %%
china_India = china_India.transpose()

# %%
china_India.head()
# Out:
# Country  China  India
# 1980      5123   8880
# 1981      6682   8670
# 1982      3308   8147
# 1983      1863   7338
# 1984      1527   5704

# %%
china_India.plot()
# Out:
# <AxesSubplot:>

# %%
simigran_by_country.sort_values(by="Total", ascending=False, inplace=True)

# %%
#hapus baris
simigran_by_country.drop(["Total"], inplace=True)

# %%
simigran_by_country
# Out:
#                                                      1980   1981   1982  \
# Country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Unknown                                             44000  18078  16904
# Philippines                                          6051   5921   5249
# ...                                                   ...    ...    ...
# San Marino                                              1      0      0
# New Caledonia                                           0      0      0
# Marshall Islands                                        0      0      0
# Western Sahara                                          0      0      0
# Palau                                                   0      0      0
#
#                                                      1983   1984   1985  \
# Country
# ...

# %%
#scripting layer plot procedural

top5 = simigran_by_country.head(5)
top5.drop(["Total"],axis=1, inplace=True)
top5 = top5.transpose()

china_India = df_can.loc[["China", "India"], years]
china_India = china_India.transpose()

top5.plot(kind="area")
plt.title("Top 5")

china_India.plot(kind="line")
plt.title("China India")

plt.show()
# Out:
# C:\Users\resty\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#artist layer

top5 = simigran_by_country.head(5)
top5.drop(["Total"],axis=1, inplace=True)
top5 = top5.transpose()

china_India = df_can.loc[["China", "India"], years]
china_India = china_India.transpose()

top5Plot= top5.plot(kind="area", figsize=(22, 10), alpha=0.3, stacked=False)
top5Plot.set_title("Top 5")
# Out:
# C:\Users\resty\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Text(0.5, 1.0, 'Top 5')

# %%
# Histogram

df_can.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
count, bin_endge = np.histogram(df_can[2013])

# %%
count
# Out:
# array([193,   3,   0,   0,   0,   0,   0,   0,   0,   1], dtype=int64)

# %%
bin_endge
# Out:
# array([     0. ,  25902.1,  51804.2,  77706.3, 103608.4, 129510.5,
#        155412.6, 181314.7, 207216.8, 233118.9, 259021. ])

# %%
df_can.describe()
# Out:
#                 1980           1981           1982          1983  \
# count     197.000000     197.000000     197.000000    197.000000
# mean     1453.167513    1306.000000    1230.203046    905.431472
# std     10784.524807    9449.373841    8864.905615   6503.149859
# min         0.000000       0.000000       0.000000      0.000000
# 25%         0.000000       0.000000       0.000000      0.000000
# 50%        14.000000      10.000000      12.000000     12.000000
# 75%       266.000000     299.000000     299.000000    197.000000
# max    143137.000000  128641.000000  121175.000000  89185.000000
#
#                1984          1985          1986           1987           1988  \
# count    197.000000    197.000000    197.000000     197.000000     197.000000
# mean     896.162437    856.304569   1008.639594    1543.908629    1640.456853
# std     6452.570413   6155.858422   7205.630681   11045.558746   11809.252241
# ...

# %%
dfhist2013c = df_can[2013].plot(kind="hist", figsize=(8,6))

# %%
top5 = simigran_by_country.head()
top5.drop("Total", axis=1, inplace=True)
top5 = top5.transpose()
top5.plot(kind="bar", figsize=(20,11), alpha=0.5);

# %%
top5 = simigran_by_country.head()
top5.drop("Total", axis=1, inplace=True)
top5 = top5.transpose()
top5.plot(kind="hist", figsize=(17,11), alpha=0.5);

# %%
chinaImigranData = simigran_by_country.loc[["China"]]
chinaImigranData.drop(["Total"], axis=1, inplace=True)
chinaImigranData = chinaImigranData.transpose()
chinaImigranDataPlot = chinaImigranData.plot(kind="bar", figsize=(20,13), alpha=0.3, color="purple" )

# %%
continent_Data = df_can.groupby("Continent").sum()

# %%
color_list = ["Purple", "yellow", "orange", "Black", "Blue", "Pink", "gray"]
explode_list = [0.1,0,0,0,0,0.1,0.1]
continenttotalPlot = continent_Data["Total"].plot(kind="pie", 
                                                  figsize = (15,5), 
                                                  colors=color_list,
                                                  explode = explode_list,
                                                  autopct="%1.1f%%",
                                                  shadow=True,
                                                  labels=None,
                                                  pctdistance=1.13,
                                                  startangle=90
                                                 )
plt.title("Immigritaion to Canada by Continent[1980 - 2013]", y=1.12)

plt.axis("equal")

#add legend
plt.legend(labels=continent_Data.index, loc= "upper left")
