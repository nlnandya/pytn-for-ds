# %%
import pandas as pd
import numpy as np

# %%
#data example = canada imigration data

df_can = pd.read_excel("Canada.xlsx", sheet_name="Canada by Citizenship", skiprows=range(20))
df_can
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2012    2013  \
# 0      Southern Asia  902  Developing regions      16  ...    2635    2004
# ...

# %%
#data teratas
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2012  2013  \
# 0    Southern Asia  902  Developing regions    16  ...  2635  2004
# 1  Southern Europe  901   Developed regions     1  ...   620   603
# 2  Northern Africa  902  Developing regions    80  ...  3774  4331
# 3        Polynesia  902  Developing regions     0  ...     0     0
# 4  Southern Europe  901   Developed regions     0  ...     1     1
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
#data terbawah
df_can.tail()
# Out:
#            Type    Coverage    OdName  AREA AreaName  REG         RegName  \
# 192  Immigrants  Foreigners     Yemen   935     Asia  922    Western Asia
# 193  Immigrants  Foreigners    Zambia   903   Africa  910  Eastern Africa
# 194  Immigrants  Foreigners  Zimbabwe   903   Africa  910  Eastern Africa
# 195  Immigrants  Foreigners   Unknown   999    World  999           World
# 196  Immigrants        Both     Total   999    World  999           World
#
#      DEV             DevName    1980  ...    2012    2013  Unnamed: 43  \
# 192  902  Developing regions       1  ...     174     217          NaN
# 193  902  Developing regions      11  ...      46      59          NaN
# 194  902  Developing regions      72  ...     437     407          NaN
# 195  999               World   44000  ...    1681    1484          NaN
# 196  999               World  143137  ...  257903  259021          NaN
#
#      Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  \
# ...

# %%
#melihat list column
df_can.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50'], dtype=object)

# %%
df_can.drop(["Coverage", "AREA", "REG", "DEV"], axis=1, inplace=True)

# %%
df_can.columns.values
# Out:
# array(['Type', 'OdName', 'AreaName', 'RegName', 'DevName', 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46',
#        'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'],
#       dtype=object)

# %%
df_can.rename(columns={"OdName":"Country", "AreaName":"Continent", "RegName":"Region"}, inplace=True)

# %%
df_can
# Out:
#            Type         Country Continent           Region  \
# 0    Immigrants     Afghanistan      Asia    Southern Asia
# 1    Immigrants         Albania    Europe  Southern Europe
# 2    Immigrants         Algeria    Africa  Northern Africa
# 3    Immigrants  American Samoa   Oceania        Polynesia
# 4    Immigrants         Andorra    Europe  Southern Europe
# ..          ...             ...       ...              ...
# 192  Immigrants           Yemen      Asia     Western Asia
# 193  Immigrants          Zambia    Africa   Eastern Africa
# 194  Immigrants        Zimbabwe    Africa   Eastern Africa
# 195  Immigrants         Unknown     World            World
# 196  Immigrants           Total     World            World
#
#                 DevName    1980    1981    1982   1983   1984  ...    2012  \
# 0    Developing regions      16      39      39     47     71  ...    2635
# 1     Developed regions       1       0       0      0      0  ...     620
# ...

# %%
df_can["Total"] = df_can.sum(axis=1)

# %%
df_can
# Out:
#            Type         Country Continent           Region  \
# 0    Immigrants     Afghanistan      Asia    Southern Asia
# 1    Immigrants         Albania    Europe  Southern Europe
# 2    Immigrants         Algeria    Africa  Northern Africa
# 3    Immigrants  American Samoa   Oceania        Polynesia
# 4    Immigrants         Andorra    Europe  Southern Europe
# ..          ...             ...       ...              ...
# 192  Immigrants           Yemen      Asia     Western Asia
# 193  Immigrants          Zambia    Africa   Eastern Africa
# 194  Immigrants        Zimbabwe    Africa   Eastern Africa
# 195  Immigrants         Unknown     World            World
# 196  Immigrants           Total     World            World
#
#                 DevName    1980    1981    1982   1983   1984  ...    2013  \
# 0    Developing regions      16      39      39     47     71  ...    2004
# 1     Developed regions       1       0       0      0      0  ...     603
# ...

# %%
df_can.isnull().sum()
# Out:
# Type             0
# Country          0
# Continent        0
# Region           0
# DevName          0
# 1980             0
# 1981             0
# 1982             0
# 1983             0
# 1984             0
# 1985             0
# 1986             0
# 1987             0
# 1988             0
# 1989             0
# 1990             0
# 1991             0
# 1992             0
# 1993             0
# 1994             0
# 1995             0
# 1996             0
# 1997             0
# 1998             0
# 1999             0
# 2000             0
# 2001             0
# 2002             0
# 2003             0
# 2004             0
# 2005             0
# 2006             0
# 2007             0
# 2008             0
# 2009             0
# 2010             0
# 2011             0
# 2012             0
# 2013             0
# Unnamed: 43    197
# Unnamed: 44    197
# Unnamed: 45    197
# Unnamed: 46    197
# Unnamed: 47    197
# Unnamed: 48    197
# Unnamed: 49    197
# Unnamed: 50    197
# ...

# %%
simigran_by_country = df_can.drop(["Continent", "Continent", "Region", "DevName", "Type"], axis=1)

# %%
simigran_by_country
# Out:
#             Country    1980    1981    1982   1983   1984   1985   1986  \
# 0       Afghanistan      16      39      39     47     71    340    496
# 1           Albania       1       0       0      0      0      0      1
# 2           Algeria      80      67      71     69     63     44     69
# 3    American Samoa       0       1       0      0      0      0      0
# 4           Andorra       0       0       0      0      0      0      2
# ..              ...     ...     ...     ...    ...    ...    ...    ...
# 192           Yemen       1       2       1      6      0     18      7
# 193          Zambia      11      17      11      7     16      9     15
# 194        Zimbabwe      72     114     102     44     32     29     43
# 195         Unknown   44000   18078   16904  13635  14855  14368  13303
# 196           Total  143137  128641  121175  89185  88272  84346  99351
#
#        1987    1988  ...    2013  Unnamed: 43  Unnamed: 44  Unnamed: 45  \
# ...

# %%
simigran_by_country.set_index("Country", inplace=True)

# %%
simigran_by_country
# Out:
#                   1980    1981    1982   1983   1984   1985   1986    1987  \
# Country
# Afghanistan         16      39      39     47     71    340    496     741
# Albania              1       0       0      0      0      0      1       2
# Algeria             80      67      71     69     63     44     69     132
# American Samoa       0       1       0      0      0      0      0       1
# Andorra              0       0       0      0      0      0      2       0
# ...                ...     ...     ...    ...    ...    ...    ...     ...
# Yemen                1       2       1      6      0     18      7      12
# Zambia              11      17      11      7     16      9     15      23
# Zimbabwe            72     114     102     44     32     29     43      68
# Unknown          44000   18078   16904  13635  14855  14368  13303   17304
# Total           143137  128641  121175  89185  88272  84346  99351  152075
#
# ...

# %%
# find by key
simigran_by_country.loc["Algeria"]
# Out:
# 1980              80.0
# 1981              67.0
# 1982              71.0
# 1983              69.0
# 1984              63.0
# 1985              44.0
# 1986              69.0
# 1987             132.0
# 1988             242.0
# 1989             434.0
# 1990             491.0
# 1991             872.0
# 1992             795.0
# 1993             717.0
# 1994             595.0
# 1995            1106.0
# 1996            2054.0
# 1997            1842.0
# 1998            2292.0
# 1999            2389.0
# 2000            2867.0
# 2001            3418.0
# 2002            3406.0
# 2003            3072.0
# 2004            3616.0
# 2005            3626.0
# 2006            4807.0
# 2007            3623.0
# 2008            4005.0
# 2009            5393.0
# 2010            4752.0
# 2011            4325.0
# 2012            3774.0
# 2013            4331.0
# Unnamed: 43        NaN
# Unnamed: 44        NaN
# Unnamed: 45        NaN
# Unnamed: 46        NaN
# Unnamed: 47        NaN
# Unnamed: 48        NaN
# ...

# %%
#find by key with specific column

simigran_by_country.loc["Algeria", range(1981, 1985)]
# Out:
# 1981    67.0
# 1982    71.0
# 1983    69.0
# 1984    63.0
# Name: Algeria, dtype: float64

# %%
df_can.set_index("Country", inplace=True)

# %%
df_can
# Out:
#                       Type Continent           Region             DevName  \
# Country
# Afghanistan     Immigrants      Asia    Southern Asia  Developing regions
# Albania         Immigrants    Europe  Southern Europe   Developed regions
# Algeria         Immigrants    Africa  Northern Africa  Developing regions
# American Samoa  Immigrants   Oceania        Polynesia  Developing regions
# Andorra         Immigrants    Europe  Southern Europe   Developed regions
# ...                    ...       ...              ...                 ...
# Yemen           Immigrants      Asia     Western Asia  Developing regions
# Zambia          Immigrants    Africa   Eastern Africa  Developing regions
# Zimbabwe        Immigrants    Africa   Eastern Africa  Developing regions
# Unknown         Immigrants     World            World               World
# Total           Immigrants     World            World               World
#
# ...

# %%
condition = df_can["Continent"] == "Europe"

# %%
condition
# Out:
# Country
# Afghanistan       False
# Albania            True
# Algeria           False
# American Samoa    False
# Andorra            True
#                   ...
# Yemen             False
# Zambia            False
# Zimbabwe          False
# Unknown           False
# Total             False
# Name: Continent, Length: 197, dtype: bool

# %%
df_can[(df_can["Continent"]=="Europe") & (df_can["Region"]=="Southern Europe")]
# Out:
#                                                  Type Continent  \
# Country
# Albania                                    Immigrants    Europe
# Andorra                                    Immigrants    Europe
# Bosnia and Herzegovina                     Immigrants    Europe
# Croatia                                    Immigrants    Europe
# Greece                                     Immigrants    Europe
# Italy                                      Immigrants    Europe
# Malta                                      Immigrants    Europe
# Montenegro                                 Immigrants    Europe
# Portugal                                   Immigrants    Europe
# San Marino                                 Immigrants    Europe
# Serbia                                     Immigrants    Europe
# Slovenia                                   Immigrants    Europe
# Spain                                      Immigrants    Europe
# ...

# %%
#tampilkan europe dan asia

df_can[(df_can["Continent"] == "Asia") | (df_can["Continent"]=="Europe")]
# Out:
#                                                           Type Continent  \
# Country
# Afghanistan                                         Immigrants      Asia
# Albania                                             Immigrants    Europe
# Andorra                                             Immigrants    Europe
# Armenia                                             Immigrants      Asia
# Austria                                             Immigrants    Europe
# ...                                                        ...       ...
# United Arab Emirates                                Immigrants      Asia
# United Kingdom of Great Britain and Northern Ir...  Immigrants    Europe
# Uzbekistan                                          Immigrants      Asia
# Viet Nam                                            Immigrants      Asia
# Yemen                                               Immigrants      Asia
#
#                                                                 Region  \
# ...

# %%
df_can["Continent"] =="Asia"
# Out:
# Country
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Unknown           False
# Total             False
# Name: Continent, Length: 197, dtype: bool

# %%
# Visualization
# matplotlib pyplot
# %matplotlib inline

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
afghanistanImigran = df_can.loc["Afghanistan", range(1980, 2013)]

# %%
afghanistanImigran
# Out:
# 1980      16
# 1981      39
# 1982      39
# 1983      47
# 1984      71
# 1985     340
# 1986     496
# 1987     741
# 1988     828
# 1989    1076
# 1990    1028
# 1991    1378
# 1992    1170
# 1993     713
# 1994     858
# 1995    1537
# 1996    2212
# 1997    2555
# 1998    1999
# 1999    2395
# 2000    3326
# 2001    4067
# 2002    3697
# 2003    3479
# 2004    2978
# 2005    3436
# 2006    3009
# 2007    2652
# 2008    2111
# 2009    1746
# 2010    1758
# 2011    2203
# 2012    2635
# Name: Afghanistan, dtype: object

# %%
afghanistanImigran.plot();

# %%
afghanistanImigran.plot(title="Immigration from Afghanistan")
# Out:
# <AxesSubplot:title={'center':'Immigration from Afghanistan'}>

# %%
afghanistanImigran.plot()
plt.title("Immigration from Afghanistan")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %%
years = range(1980, 2014)

# %%
years
# Out:
# range(1980, 2014)

# %%
china_India = df_can.loc[["China", "India"], years]
china_India
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
china_India.plot()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
china_India = china_India.transpose()
china_India.head()
# Out:
# Country  China  India
# 1980      5123   8880
# 1981      6682   8670
# 1982      3308   8147
# 1983      1863   7338
# 1984      1527   5704

# %%
china_India.plot()
# Out:
# <AxesSubplot:>

# %%
simigran_by_country.sort_values(by="Total", ascending=False, inplace=True)

# %%
simigran_by_country = simigran_by_country.iloc[1: simigran_by_country.shape[0]]

# %%
# Out:
# C:\Users\resty\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-228-164611864c2c> in <module>
#       2 top5.drop(["Total"], axis=1, inplace=True)
#       3 top5 = top5.transpose()
# ----> 4 chi
#       5 top5.plot(kind="line", figsize=(10,9))
#       6 plt.show()
#
# NameError: name 'chi' is not defined

# %%
#Histograms

df_can[2013].head()

# %%
count, bin_endge = np.histogram(df_can[2013])

# %%
count

# %%
bin_endge

# %%
dfhist2013c = df_can[2013].plot(kind="hist", figsize=(8,6))

# %%
#pie chart

continent_df = df_can["Continent"]

# %%
df_can.head()
# Out:
#                       Type Continent           Region             DevName  \
# Country
# Afghanistan     Immigrants      Asia    Southern Asia  Developing regions
# Albania         Immigrants    Europe  Southern Europe   Developed regions
# Algeria         Immigrants    Africa  Northern Africa  Developing regions
# American Samoa  Immigrants   Oceania        Polynesia  Developing regions
# Andorra         Immigrants    Europe  Southern Europe   Developed regions
#
#                 1980  1981  1982  1983  1984  1985  ...  2013  Unnamed: 43  \
# Country                                             ...
# Afghanistan       16    39    39    47    71   340  ...  2004          NaN
# Albania            1     0     0     0     0     0  ...   603          NaN
# Algeria           80    67    71    69    63    44  ...  4331          NaN
# American Samoa     0     1     0     0     0     0  ...     0          NaN
# Andorra            0     0     0     0     0     0  ...     1          NaN
#
# ...

# %%
continent_Data = df_can.groupby("Continent", axis=0).sum()

# %%
continenttotalPlot = continent_Data["Total"].plot(kind="pie", figsize=(8,8))
